# %%
import sys

sys.modules
# Out:
# {'matplotlib.axes._axes': <module 'matplotlib.axes._axes' from '/usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py'>,
#  'tensorflow.python.training.slot_creator': <module 'tensorflow.python.training.slot_creator' from '/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/slot_creator.py'>,
#  'zlib': <module 'zlib' (built-in)>,
#  'pyparsing': <module 'pyparsing' from '/usr/lib/python3/dist-packages/pyparsing.py'>,
#  'IPython.utils._process_posix': <module 'IPython.utils._process_posix' from '/usr/local/lib/python3.5/dist-packages/IPython/utils/_process_posix.py'>,
#  'IPython.core.shellapp': <module 'IPython.core.shellapp' from '/usr/local/lib/python3.5/dist-packages/IPython/core/shellapp.py'>,
#  'jupyter_client.connect': <module 'jupyter_client.connect' from '/usr/local/lib/python3.5/dist-packages/jupyter_client/connect.py'>,
#  'traitlets.log': <module 'traitlets.log' from '/usr/local/lib/python3.5/dist-packages/traitlets/log.py'>,
# ...

# %%
sys.another = 'hello'

sys.another
# Out:
# 'hello'

# %%
sys.__dict__
# Out:
# {'__displayhook__': <function sys.displayhook>,
# ...

# %%
sys.__name__, sys.__dict__['__name__']
# Out:
# ('sys', 'sys', '')

# %%
sys.__file__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8e158a6bd20a> in <module>()
# ----> 1 sys.__file__
#
# AttributeError: module 'sys' has no attribute '__file__'

# %%
import tensorflow as tf
import tensorflow.contrib as contrib
tf.__file__, tf.__package__, tf.__path__#, tf.__all__
# Out:
# ('/usr/local/lib/python3.5/dist-packages/tensorflow/__init__.py',
#  'tensorflow',
#  ['/usr/local/lib/python3.5/dist-packages/tensorflow'])
